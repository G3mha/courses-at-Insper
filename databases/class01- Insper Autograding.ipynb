# %% [markdown]
# # Insper Autograding
#
# Siga os passos deste notebook para realizar a instalação da biblioteca de correção de exercícios nos notebooks da disciplina de Megadados!
#
# ## Instalação
#
# Vamos instalar a biblioteca:

# %%
# !pip uninstall -y insperautograder
# !pip install git+https://github.com/macielcalebe/insperautograding.git
# Out:
# Found existing installation: insperautograder 0.1.0
# Uninstalling insperautograder-0.1.0:
#   Successfully uninstalled insperautograder-0.1.0
# Collecting git+https://github.com/macielcalebe/insperautograding.git
#   Cloning https://github.com/macielcalebe/insperautograding.git to c:\users\enricco gemha\appdata\local\temp\pip-req-build-vdp7gpr3
#   Resolved https://github.com/macielcalebe/insperautograding.git to commit 4a8520568b7d385f9dba29e6c359f43559603f6d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: python-dotenv in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from insperautograder==0.1.0) (1.0.0)
# Requirement already satisfied: requests in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from insperautograder==0.1.0) (2.31.0)
# Requirement already satisfied: ipython in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from insperautograder==0.1.0) (8.12.0)
# Requirement already satisfied: ipywidgets in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from insperautograder==0.1.0) (8.0.6)
# Requirement already satisfied: backcall in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (0.2.0)
# Requirement already satisfied: decorator in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (5.9.0)
# Requirement already satisfied: colorama in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipython->insperautograder==0.1.0) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipywidgets->insperautograder==0.1.0) (6.22.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->insperautograder==0.1.0) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->insperautograder==0.1.0) (3.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from requests->insperautograder==0.1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from requests->insperautograder==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from requests->insperautograder==0.1.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (from requests->insperautograder==0.1.0) (2023.7.22)
# Requirement already satisfied: comm>=0.1.1 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (8.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (1.5.6)
# Requirement already satisfied: packaging in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (23.0)
# Requirement already satisfied: psutil in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->insperautograder==0.1.0) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->insperautograder==0.1.0) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from stack-data->ipython->insperautograder==0.1.0) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from stack-data->ipython->insperautograder==0.1.0) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from stack-data->ipython->insperautograder==0.1.0) (0.2.2)
# Requirement already satisfied: six in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from asttokens>=2.1.0->stack-data->ipython->insperautograder==0.1.0) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\enricco gemha\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->insperautograder==0.1.0) (306)
# Building wheels for collected packages: insperautograder
#   Building wheel for insperautograder (pyproject.toml): started
#   Building wheel for insperautograder (pyproject.toml): finished with status 'done'
#   Created wheel for insperautograder: filename=insperautograder-0.1.0-py3-none-any.whl size=3627 sha256=695e043c76d177af13752d0e7c20631d7c712a1d5219bd94fc45c62ca087b4b4
#   Stored in directory: C:\Users\Enricco Gemha\AppData\Local\Temp\pip-ephem-wheel-cache-zd5t5e_d\wheels\bb\01\cc\7f397587bfedd6c633e2627496c45d5693aa959ee8237ead1f
# Successfully built insperautograder
# Installing collected packages: insperautograder
# Successfully installed insperautograder-0.1.0
#   Running command git clone --filter=blob:none --quiet https://github.com/macielcalebe/insperautograding.git 'C:\Users\Enricco Gemha\AppData\Local\Temp\pip-req-build-vdp7gpr3'

# %% [markdown]
# ## Criar o `.env`
#
# Os arquivos `.env` são arquivos de configuração usados no desenvolvimento de software para armazenar variáveis de ambiente. **Variáveis de ambiente** são valores definidos **fora do código-fonte** e usados para configurar diferentes aspectos de um aplicativo, como strings de conexão de banco de dados, chaves de API e outras **informações confidenciais**.
#
# Arquivos `.env` **jamais** (EU DISSE JAMAAAAIS) devem ser enviados para o github, isto pode representar sérios riscos pois pode prover acesso indevidos, como:
# - O hacker acessa e apaga toda sua base de dados
# - O hacker usa sua chave de API da AWS para minerar criptomoedas ou enviar spam (pode gastar milhares de dólares em minutos ou horas)
#
# Vamos instalar a biblioteca

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\enricco gemha\appdata\local\programs\python\python311\lib\site-packages (1.0.0)

# %% [markdown]
# e escrever um `.env` na pasta pai (supondo que você tem uma pasta para a disciplina e nela cria uma pasta por aula).
#
# <img src="https://megadados-insper.s3.us-east-2.amazonaws.com/img/env_local.png">
#
# O comando abaixo já deve escrever no local adequado. Você também pode utilizar um editor de textos para criar o `.env`.

# %%
# %%writefile ../.env
# IAG_SERVER_URL="https://bigdata.insper-comp.com.br/iag"
# IAG_SUBJECT="megadados"
# IAG_OFFERING="23-2"
# IAG_TOKEN="iagtok_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
# Out:
# Writing ../.env

# %% [markdown]
# Confira pelo navegador de arquivos se o `.env` foi gerado corretamente!
#
# Como uma segunda confirmação, vamos tentar ler o endereço do servidor:

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)

# Se aparecer o mesmo conteúdo definido na variável no .env, então é sucesso!
print(os.getenv('IAG_SERVER_URL'))
# Out:
# https://bigdata.insper-comp.com.br/iag

# %% [markdown]
# ## Gerar um token
#
# Vamos fazer uma requisição para gerar um token que será utilizado para identificar você nos envios da disciplina.
#
# Caso algum import falha, faça `pip install`

# %%
import insperautograder.token as iat
import insperautograder.jupyter as iaj

# %%
# Descomente as linhas abaixo!
username = 'enriccog' # Informe aqui seu usuário Insper ex: mariana5 (sem @al....)
iat.get_new_token(username=username)
# Out:
# "Sending token in background! Check your Insper E-mail!"

# %% [markdown]
# Confira seu email. Copie o token e cole no arquivo `.env` gerado no passo anterior. Como o token é a única informação sensível no `.env`, ao invés de atualizar pelo jupyter notebook, abra em algum editor de textos.
#
# Após a edição, execute a próxima célula para atualizar as variáveis de ambiente:

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## Testando a API!
#
# **Exercício exemplo**: Qual o nome desta disciplina?! Responda como string na variável `resp` (próxima célula).
#
# Considere que a seguinte resposta está correta, vamos fazer seu envio!

# %%
resp = '''
 MEGADADOS
'''

# %% [markdown]
# Para enviar, clique no botão:

# %%
iaj.sender(answer='resp', task='newborn', question='ex01', answer_type='pyvar')
# Out:
# interactive(children=(Button(description='Enviar ex01', style=ButtonStyle()), Output()), _dom_classes=('widget…

# %% [markdown]
# Perceba que a query possui um erro. Faça a correção, e, após sua última modificação, faça o envio clicando novamente no botão de envio! Ele automaticamente irá ler a variável `sql` (pega o valor atual dela, definido na última vez que você rodou a célula) e enviar para o servidor de testes!

# %% [markdown]
# ## Atividades e Notas
#
# Podemos utilizar as chamadas para recuperar as atividades disponíveis, prazos e notas obtidas:

# %%
iaj.tasks()
# Out:
# |    | Atividade   | De                        | Até                       |
# |---:|:------------|:--------------------------|:--------------------------|
# |  0 | newborn     | 2023-08-08 03:00:00+00:00 | 2023-08-16 02:59:59+00:00 |

# %%
iaj.grades(task='newborn')
# Out:
# |    | Atividade   | Exercício   |   Peso |   Nota |
# |---:|:------------|:------------|-------:|-------:|
# |  0 | newborn     | ex01        |      1 |     10 |

# %%
iaj.grades(by='TASK', task='newborn')
# Out:
# |    | Tarefa   |   Nota |
# |---:|:---------|-------:|
# |  0 | newborn  |     10 |
