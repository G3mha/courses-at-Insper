# %% [markdown]
# ___
# # Exercício: Teoria da Probabilidade
# ___
#
# ## Aula 05

# %% [markdown]
# <div id="indice"></div>
#
# ## Índice
#
# - [Exercício 1](#ex1) **- Use a solução como referência para os demais exercícios**
# - [Exercício 2](#ex2) **- APS3 disponível no Blackboard**
# - [Exercício 3](#ex3) **- APS3 disponível no Blackboard**
# - [Exercício 4](#ex4)
# - [Exercício 5](#ex5) **- APS3 disponível no Blackboard**
# - [Exercício 6](#ex6)
# - [Exercício 7](#ex7) **- APS3 disponível no Blackboard**
#
# <br>
#
# **Obs.:**
#  1. Os exercícios que não constam na **APS3**, você encontra as respostas nos slides.🎉
#  ___

# %% [markdown]
# ___
# <div id="ex1"></div>
#
# ### EXERCÍCIO 1:
#
# A probabilidade de que o preço dos combustíveis aumente no mês vindouro é estimada em 0,4.
#
# Se isto ocorrer, a probabilidade de que os preços dos transportes coletivos também aumentem é de 0,5; caso contrário, esta probabilidade é de 0,1.
#
# Se naquele mês o preço das passagens de fato subirem, qual a probabilidade de os preços dos combustíveis não terem sofrido majoração?
# ___

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  * $C$: aumento do preço do combustível
#  * $C^c$: não aumento do preço do combustível
#  * $T$: aumento do preço do transporte
#  * $T^c$: não aumento do preço do transporte

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(C)=0.4$
#  * $P(T|C)=0.5$
#  * $P(T|C^c)=0.1$

# %%
# Enunciado
P_C = 0.4
P_T_dado_C = 0.5
P_T_dado_Cc = 0.1

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(C^c|T)=?$

# %% [markdown]
# **Resolução:**
#
# A probabilidade condicional solicitada é dada por
#
# $P(C^c|T) = \frac{P(T \cap C^c)}{P(T)}$
#
# Logo, primeiro é necessário calcular $P(T \cap C^c)$ e $P(T)$.

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Use este exercício como guia para deixar claro o uso da notação para  
# a resolução do exercício

# %%
# P_TeCc = P_Cc * P_T_dado_Cc
P_Cc = 1 - P_C
P_TeCc = P_Cc*P_T_dado_Cc

# %%
#P_T = P_TeC + P_TeCc

P_TeC = P_C*P_T_dado_C
P_TeCc = P_Cc*P_T_dado_Cc

P_T = P_TeC + P_TeCc
P_T
# Out:
# 0.26

# %%
#Logo,
#P(Cc|T) = P_TeCc / P_T

P_Cc_dado_T = P_TeCc / P_T

# %%
print(f'Na condição do preço do transporte subir, a probabilidade de não ter sido ocasionado '
      f'pelo aumento do combustível é {P_Cc_dado_T:.4g}.')
# Out:
# Na condição do preço do transporte subir, a probabilidade de não ter sido ocasionado pelo aumento do combustível é 0.2308.

# %% [markdown]
# ___
# <div id="ex2"></div>
#
# ### EXERCÍCIO 2:
#
# Uma revendedora de veículos trabalha com duas marcas de automóveis: A e B. 70% dos que adquirem carros populares, escolhem a marca A. Dentre os que adquirem carros não populares, 80% compram A. Sabe-se que 60% das vendas são de carros populares.
#
# a. Qual é a probabilidade de um consumidor comprar um carro da marca A?
#
# b. Sabendo que uma pessoa comprou um carro da marca A, qual é a probabilidade de ter sido um carro popular?
# ___

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  * $A$: escolha de carro da marca A
#  * $B$: escolha de carro da marca B
#  * $P$: escolha de carro popular
#  * $Pc$: escolha de carro não popular

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(P) = 0.6$
#  * $P(A|P) = 0.7$
#  * $P(A|Pc) = 0.8$

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * a) $P(A) = ?$
#  * b) $P(P|A) = ?$

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Coloque seu código aqui
P_A_dado_P = 0.7
P_A_dado_Pc = 0.8
P_P = 0.6
P_Pc = 1 - P_P


P_AeP = P_P*P_A_dado_P
P_AePc = P_Pc*P_A_dado_Pc

P_A = P_AeP + P_AePc
P_A
# Out:
# 0.74

# %%
P_P_dado_A = P_AeP / P_A
round(P_P_dado_A,5)
# Out:
# 0.56757

# %% [markdown]
# ___
# <div id="ex3"></div>
#
# ### EXERCÍCIO 3 - Capítulo 2 de Montgomery e Runger (2016):
#
# Em uma operação de enchimento automático, a probabilidade de um enchimento incorreto será 0,001, quando o processo for operado em baixa velocidade. Quando o processo for operado em alta velocidade, a probabilidade de um enchimento incorreto será de 0,01.
#
# Suponha de 30% dos reservatórios sejam cheios quando o processo for operado em alta velocidade, e o restante seja cheio em baixa velocidade.
#
# a. Qual a probabilidade de um reservatório ser cheio incorretamente?
#
# b. Se um reservatório cheio incorretamente for encontrado, qual é a probabilidade de que ele tenha sido cheio durante uma operação em alta velocidade?
# ___

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  * $Ac$: processo de enchimento em baixa velocidade
#  * $A$: processo de enchimento em alta velocidade
#  * $Ec$: enchimento incorreto
#  * $E$: enchimento correto

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(Ec|Ac)$ = 0.001
#  * $P(Ec|A)$ = 0.01
#  * $P(A) = 0.3$
#  * $P(Ac) = 0.7$

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * a) $P(Ec) = ?$
#  * b) $P(A|Ec) = ?$

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Coloque seu código aqui
P_Ec_dado_Ac = 0.001
P_Ec_dado_A = 0.01
P_A = 0.3
P_Ac = 0.7

P_EceA = P_A*P_Ec_dado_A
P_EceAc = P_Ac*P_Ec_dado_Ac

P_Ec = P_EceA + P_EceAc
P_Ec
# Out:
# 0.0037

# %%
P_A_dado_Ec = P_EceA / P_Ec
round(P_A_dado_Ec, 5)
# Out:
# 0.81081

# %% [markdown]
# ___
# <div id="ex4"></div>
#
# ### EXERCÍCIO 4:
#
# O gerente de um posto de gasolina sabe da sua experiência que 80% dos clientes usam cartão de crédito quando compram gasolina.
#
# Admita independência entre clientes.
#
# a. Qual é a probabilidade dos dois próximos clientes comprarem gasolina usando cartão de crédito ?
#
# b. E de pelo menos 1 usar cartão de crédito?
#
# *Resposta esperada para itens (a) e (b) respectivamente: 64% ; 96%*
#
# ___

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  * $C$: pagar utilizando cartão de crédito
#  * $Cc$: pagar utilizando uma forma de pagamento que não seja cartão de crédito

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(C) = 0.8$
#  * $P(Cc) = 0.2$

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * a) $P(C) * P(C)$
#  * b) $P(min(1C)|2)$

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Coloque seu código aqui
P_C = 0.8
P_Cc = 0.2

print(round(P_C*P_C,5))
# Out:
# 0.64

# %%
Pdesejada = 1 - (P_Cc * P_Cc)

print(round(Pdesejada, 5))
# Out:
# 0.96

# %% [markdown]
# ___
# <div id="ex5"></div>
#
# ### EXERCÍCIO 5 - Capítulo 2 de Montgomery e Runger (2016):
#
#
# Um sistema de codificação-decodificação consiste em três elementos: codifica, transmite e decodifica.
#
# Uma codificação falha ocorre em 0,5% das mensagens processadas; erro de transmissão ocorrem em 1% das mensagens;  e erro de decodificação ocorre em 0,1% das mensagens. Considere os erros como independentes.
#
# a. Qual a probabilidade de se ter uma mensagem completamente livre de defeito?
#
# b. Qual a probabilidade de uma mensagem ter tanto um defeito de codificação como de decodificação?
# ___

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  * $C$: processo de codificação
#  * $Cc$: processo de codificação falho
#  * $T$: processo de transmissão
#  * $Tc$: processo de transmissão falho
#  * $D$: processo de decodificação
#  * $Dc$: processo de decodificação falho

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(Cc) = 0.005$
#  * $P(Tc) = 0.01$
#  * $P(Dc) = 0.001$

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * a) $P(C|T|D) = ?$
#  * b) $P(Cc|Dc) =?$

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Coloque seu código aqui
P_Cc = 0.005
P_Tc = 0.01
P_Dc = 0.001

P_C = 1-P_Cc
P_T = 1-P_Tc
P_D = 1-P_Dc

P_C_T_D = P_C * P_T * P_D
round(P_C_T_D,5)
# Out:
# 0.98406

# %%
1e-05 * 10**5
# Out:
# 1.0

# %%
P_Cc_Dc = P_Cc * P_Dc
P_Cc_Dc
# Out:
# 5e-06

# %% [markdown]
# ___
# <div id="ex6"></div>
#
# ### EXERCÍCIO 6: &#x2605;&#x2605;&#x2605;
#
# Considerando apenas os países que ganharam pelo menos uma medalha nos Jogos Olímpicos de 2012, as seguintes probabilidades foram observadas ao analisar, conjuntamente, o índice de desenvolvimento humano (IDH ≥ 0,75 ou IDH < 0,75) de 2011 e o tipo de medalha olímpica (ouro, prata ou bronze).
#
# A probabilidade de um atleta, que pertence a um destes países, ganhar uma medalha de ouro é de 31,5%.
# Se um país tem IDH igual ou superior a 0,75, então a probabilidade de um atleta ganhar uma medalha de ouro é 35,0% e, na mesma condição, a de um atleta ganhar uma medalha de prata é de 32,9%.
#
# Entre países com IDH inferior a 0,75, a probabilidade de um atleta ganhar uma medalha de ouro é 23,3%.
#
# Por fim, se um atleta ganhou uma medalha de bronze, a probabilidade de que ele pertença a um país com IDH inferior a 0,75 é de 38,4%.
#
# Considerando apenas os países que ganharam pelo menos uma medalha nos Jogos Olímpicos de 2012, responda:
#
# a) Qual a probabilidade de um atleta ser de um país com IDH igual ou superior a 0,75?
#
# b) Qual a probabilidade de uma medalha de prata pertencer a um atleta que representa um país com IDH igual ou superior a 0,75?
#
# c) Com base nos resultados mencionados que consideram apenas países que ganharam pelo menos uma medalha nas Olimpíadas de Londres, o IDH de um destes países pode influenciar o tipo de medalha que um atleta pode ganhar? Justifique sua resposta considerando informações numéricas.
#
#
# *Resposta esperada para itens (a) e (b) respectivamente: 70.085%; 72.106%*

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  *
#  *

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  *
#  *

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * a)
#  * b)
#  * c)

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Coloque seu código aqui

# %% [markdown]
# ___
# <div id="ex7"></div>
#
# ### EXERCÍCIO 7: &#x2605;&#x2605;&#x2605;
#
# Considere que, de todas as batidas de pênalti feitas pelo jogador Petersen da Alemanha, tenham os seguintes resultados:
# 50% dessas batidas foram no lado direito do goleiro;
# Das batidas feitas no lado direito do goleiro, 85,0% foram em partidas que se sentiu mais relaxado;
# Das batidas feitas em partidas relaxadas, 91,9% foram feitas no lado direito do goleiro;
# Assuma que "partida relaxada" e "partida nervosa" sejam eventos complementares;
# Assuma que "lado direito do goleiro" e "lado esquerdo do goleiro" sejam eventos complementares.
# Responda cada item abaixo, definindo os eventos necessários e considerando, na sua resolução, as notações vistas em aula. Utilize 3 casas decimais na resolução dos itens.
#
#
# a. Calcule a probabilidade das batidas de pênalti terem acontecido em partidas relaxadas.
#
# b. Das batidas de pênalti feitas em partidas nervosas, calcule a probabilidade de terem acontecido no lado esquerdo do goleiro.

# %% [markdown]
# ___

# %% [markdown]
# **DEFINA OS EVENTOS APRESENTADOS NO ENUNCIADO:**
#
#  * $D$: batidas no lado direito do goleiro
#  * $E$: batidas no lado esquerdo do goleiro
#  * $R$: partidas em que ele se sentiu relaxado
#  * $N$: partidas em que ele se sentiu nervoso

# %% [markdown]
# **DEFINA AS PROBABILIDADES APRESENTADAS NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * $P(D)= 0.5$
#  * $P(R|D)= 0.85$
#  * $P(D|R)= 0.919$

# %% [markdown]
# **QUAL A PROBABILIDADE SOLICITADA NO ENUNCIADO EM TERMOS DOS EVENTOS:**
#
#  * a) $P(R)$
#  * b) $P(E|N)$

# %% [markdown]
# **Deixe claro todo o raciocínio usado para chegar na probabilidade questionada:**

# %%
# Coloque seu código aqui
P_D = 0.5
P_R_dado_D = 0.85
P_D_dado_R = 0.919


P_R = P_D * P_R_dado_D / P_D_dado_R
round(P_R, 3)
# Out:
# 0.462

# %%
P_N = 1 - P_R
P_E = 1 - P_D


P_DeR = P_R*P_D_dado_R
P_DeN = P_D - P_DeR
P_D_dado_N = P_DeN / P_N
P_N_dado_D = P_N * P_D_dado_N / P_D

P_N_dado_D = P_N * P_D_dado_N / P_D
P_NeD = P_D*P_N_dado_D

P_NeE = P_N - P_NeD

P_E_dado_N = P_NeE / P_N
round(P_E_dado_N, 3)
# Out:
# 0.86
